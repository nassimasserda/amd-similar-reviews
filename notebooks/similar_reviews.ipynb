# %% [markdown]
# <a href="https://colab.research.google.com/github/nassimasserda/amd-similar-reviews/blob/main/notebooks/similar_reviews.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# installing kaggle, pandas, spacy and the dataset

# !pip install kaggle pandas spacy --quiet

import os
os.environ['KAGGLE_USERNAME'] = "jojoberni"
os.environ['KAGGLE_KEY']      = "8671f68184266cf1775f5a2d4d7be248"

# folder for the CSV
# !mkdir -p data

# !kaggle datasets download -d mohamedbakhet/amazon-books-reviews -p data --unzip

# !ls data | head -n 10
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mohamedbakhet/amazon-books-reviews
# License(s): CC0-1.0
# ...
#  99% 1.05G/1.06G [00:22<00:00, 22.1MB/s]
# 100% 1.06G/1.06G [00:22<00:00, 51.5MB/s]
# books_data.csv
# Books_rating.csv

# %%
#visualising the csv raws titles

import pandas as pd

chemin_csv = "data/Books_rating.csv"
df_header = pd.read_csv(chemin_csv, nrows=0)
print("Raws in the CSV :\n", df_header.columns.tolist())
# Out:
# Raws in the CSV :
#  ['Id', 'Title', 'Price', 'User_id', 'profileName', 'review/helpfulness', 'review/score', 'review/time', 'review/summary', 'review/text']

# %%
# uploading CSV and raw selection

import pandas as pd

chemin_csv = "data/Books_rating.csv"

# Subsampling the dataset to keep 10000 rows
SUBSAMPLE_RATIO = 0.1
nrows_test = int(100000 * SUBSAMPLE_RATIO)

# keeping only the necessary columns for the project
df_raw = pd.read_csv(
    chemin_csv,
    nrows=nrows_test,
    usecols=["Id", "User_id", "review/text"]
)

print("Dataframe shape:", df_raw.shape)
df_raw.head(5)
# Out:
# Shape du DataFrame (échantillon) : (10000, 3)
#            Id         User_id  \
# 0  1882931173   AVCGYZL8FQQTD
# 1  0826414346  A30TK6U7DNS82R
# 2  0826414346  A3UH4UZ4RSVO82
# 3  0826414346  A2MVUWT453QH61
# 4  0826414346  A22X4XUPKF66MR
#
#                                          review/text
# 0  This is only for Julie Strain fans. It's a col...
# 1  I don't care much for Dr. Seuss but after read...
# 2  If people become the books they read and if "t...
# 3  Theodore Seuss Geisel (1904-1991), aka &quot;D...
# 4  Philip Nel - Dr. Seuss: American IconThis is b...

# %%
# spacy small english model installing

# !python -m spacy download en_core_web_sm --quiet

import spacy
import string

# Uploading SpaCy without the parser/NER to go faster
nlp = spacy.load("en_core_web_sm", disable=["parser", "ner"])

print("SpaCy model uploaded:", nlp.meta["name"])
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 34.4 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# SpaCy model uploaded: core_web_sm
